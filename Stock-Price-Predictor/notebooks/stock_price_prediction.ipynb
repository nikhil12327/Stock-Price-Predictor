# %% [markdown]
# # Stock Price Predictor
# Sample notebook demonstrating the included scripts and sample data.

# %%
import pandas as pd
pd.set_option('display.width', 120)
df = pd.read_csv('data/aapl_sample.csv')
df.head()

# %%
from src.preprocessing import prepare_features
X,y,dfp = prepare_features('data/aapl_sample.csv')
print('Rows after feature engineering:', len(dfp))

# %%
from src.model import train_and_save
train_and_save(data_csv='data/aapl_sample.csv', out_model='model/stock_model.pkl')
